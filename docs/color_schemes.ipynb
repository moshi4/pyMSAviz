# %% [markdown]
# # Color Schemes

# %% [markdown]
# Color schemes equivalent to [Jalview](https://www.jalview.org/help/html/colourSchemes/) are available in pyMSAviz.

# %% [markdown]
# ## Available Color Schemes

# %%
from pymsaviz import MsaViz

print(MsaViz.available_color_schemes())
# Out:
# ['Clustal', 'Zappo', 'Taylor', 'Flower', 'Blossom', 'Sunset', 'Ocean', 'Hydrophobicity', 'HelixPropensity', 'StrandPropensity', 'TurnPropensity', 'BuriedIndex', 'Nucleotide', 'Purine/Pyrimidine', 'None']

# %% [markdown]
# ## Example of Color Scheme

# %%
from pymsaviz import MsaViz, get_msa_testdata

msa_file = get_msa_testdata("MRGPRG.fa")
for color_scheme in MsaViz.available_color_schemes():
    mv = MsaViz(msa_file, start=100, end=160, color_scheme=color_scheme, show_label=False)
    fig = mv.plotfig()
    fig.suptitle(f"Color Scheme = {color_scheme}", x=0.5, y=1.15, va="bottom", size=15)
